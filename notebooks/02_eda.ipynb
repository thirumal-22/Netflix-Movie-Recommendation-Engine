# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/cleaned_netflix_ratings.csv")

rating_counts = df["Rating"].value_counts().sort_index()

plt.figure(figsize=(6,4))
rating_counts.plot(kind="bar")
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
genre_stats = df.groupby("Genre").agg(
    avg_rating=("Rating", "mean"),
    total_ratings=("Rating", "count"),
    total_movies=("MovieID", "nunique")
).sort_values("avg_rating", ascending=False)

print(genre_stats)
# Out:
#              avg_rating  total_ratings  total_movies
# Genre
# Thriller       3.728814            118             9
# Action         3.593220            177            15
# Horror         3.516892            296            25
# Animation      3.506849             73             6
# Drama          3.431449           4865           408
# Documentary    3.386555            119             9
# Sci-Fi         3.350877            114            10
# Romance        3.326531             49             4
# Fantasy        3.298969             97             8
# Comedy         3.180328             61             6
