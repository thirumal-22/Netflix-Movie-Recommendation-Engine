# %%
import pandas as pd

df = pd.read_csv("/Users/kummarithirumalaraju/Desktop/netflix-recommendation-engine/data/netflix_ratings.csv")

print(df.head())
print(df.info())
print(df.isnull().sum())
print(df.duplicated().sum())

df.drop_duplicates(inplace=True)

df["CustomerID"] = df["CustomerID"].astype(int)
df["MovieID"] = df["MovieID"].astype(int)
df["Rating"] = df["Rating"].astype(int)
df["Year"] = df["Year"].astype(int)

df.to_csv("../data/cleaned_netflix_ratings.csv", index=False)

print("Cleaned data saved successfully")
# Out:
#    CustomerID  MovieID  Rating  \
# 0           1      365       4
# 1           1       75       4
# 2           1      379       5
# 3           1      157       4
# 4           1      106       4
#
#                                                Title  Genre    Year
# 0                                   R.E.M.: Tourfilm  Drama  1989.0
# 1                                              Grind  Drama  1997.0
# 2                                         Crash Dive  Drama  1996.0
# 3                       Laird: White Knuckle Extreme  Drama  2004.0
# 4  Stevie Ray Vaughan and Double Trouble: Live at...  Drama  2004.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5969 entries, 0 to 5968
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  5969 non-null   int64
#  1   MovieID     5969 non-null   int64
#  2   Rating      5969 non-null   int64
#  3   Title       5969 non-null   object
#  4   Genre       5969 non-null   object
#  5   Year        5969 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 279.9+ KB
# None
# CustomerID    0
# MovieID       0
# Rating        0
# Title         0
# Genre         0
# Year          0
# dtype: int64
# 0
# Cleaned data saved successfully
